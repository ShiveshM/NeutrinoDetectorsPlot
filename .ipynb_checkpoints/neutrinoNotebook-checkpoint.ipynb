# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# water cherenkov detectors
wCherenkovDetectors = ["AMANDA-A", "AMANDA-B10", "AMANDA-II", "ANNIE-I", "ANTARES","Baikal NT-200", "Baikal NT-200+", "Baikal GVD", "Hyper-K", "IC-DeepCore", "IC-Pingu", "IceCube", "Kamiokande", "SK-I", "SK-II", "SK-III", "SK-IV", "SNO"]
wCherenkovYears = [1996, 1997, 2000, 2016, 2008, 1993, 2005, 2020, 2025, 2011, 2020, 2010, 1983, 1996, 2002, 2006, 2008, 1999]
wCherenkovSpatRes = [2.62, 4.93, 6.03, 0.182, 4.65, 2.12, 2.12, 6.98, 0.22, 3.92, 1.91, 13.99, 0.21, 0.16, 0.23, 0.16, 0.16, 0.15]
wCherenkovMasses=[1.14e08, 5.89e08, 3.78e10, 23586, 3.5e10, 2e08, 2e08, 1e21, 335658354, 27215542200, 5443108440, 1e21, 2721544, 45359237,45359237,45359237,45359237, 30000]

# MO cherenkov detectors
moCherenkovDetectors = ["LSND"]
moCherenkovYears = [1993]
moCherenkovSpatRes = [0.14]
moCherenkovMasses = [151500]

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.scatter(wCherenkovYears, wCherenkovSpatRes, color='mediumseagreen', label='water cherenkov')
ax.scatter(moCherenkovYears, moCherenkovSpatRes, color='lightsalmon', label='mineral oil cherenkov')
ax.legend(loc='upper left')
ax.set_yscale('log')

for i, txt in enumerate(wCherenkovDetectors):
    ax.annotate(txt, (wCherenkovYears[i]+1.0, wCherenkovSpatRes[i]), color='mediumseagreen')

for i, txt, in enumerate(moCherenkovDetectors):
    ax. annotate(txt, (moCherenkovYears[i]+1.0, moCherenkovSpatRes[i]), color='lightsalmon')
    
plt.ylim(0.001, 100)
plt.ylabel('Spatial Resolution [m]')
plt.xlabel('Completion Year')
plt.xlim(1950, 2035)

    
plt.show()
